# %% [markdown]
# # Latihan 1.2
#
# Nicholas Emanuel Fade 5027231070

# %% [markdown]
# # no 1

# %% [markdown]
# Range

# %%
def range(data):
    nilai_tertinggi = max(data)
    print(f"Nilai tertinggi: {nilai_tertinggi}")

    nilai_terendah = min(data)
    print(f"Nilai terendah: {nilai_terendah}")

    data_range = max(data) - min(data)
 
    print(f"Range: {nilai_tertinggi} - {nilai_terendah} = {data_range}")  
    
    return data_range


data = [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
print(f"Data: {data}")

data_range = range(data)
# Out:
# Data: [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
# Nilai tertinggi: 19
# Nilai terendah: 9
# Range: 19 - 9 = 10

# %%
import matplotlib.pyplot as plt

def range(data):
    nilai_tertinggi = max(data)
    nilai_terendah = min(data)
    data_range = max(data) - min(data)
    return data_range

plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='yellow')

y = 1.5 # The y-coordinate where the line will be drawn
x1 = 4/70*1  # The x-coordinate of the start point
x2 = 66/70*1  # The x-coordinate of the end point


plt.axhline(y=y, xmin=x1, xmax=x2, color='red', linestyle='dashed', linewidth=1, label=f'Range = {range(data)}')

plt.axvline(x=min(data), color='blue', linestyle='dashed', linewidth=1, label=f'Min Data: {min(data):.2f}')
plt.axvline(x=max(data), color='blue', linestyle='dashed', linewidth=1, label=f'Max Data: {max(data):.2f}')


plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Range')


plt.legend()


plt.show()

# %% [markdown]
# Standar Deviasi dan Variansi

# %%
def calculate_mean(data):
    return sum(data) / len(data)

def calculate_variance(data):
    # Rata-rata 
    mean = calculate_mean(data)
    print(f"Rata-rata: {mean}")  
    
    squared_diff = []
    for x in data:
        squared_diff_per_x = (x - mean)**2
        squared_diff.append( squared_diff_per_x ) 
    
    variance = sum(squared_diff) / len(data)
     
    print(f"Variansi: {sum(squared_diff)} / {len(data)} = {variance}")    
    
    return variance

def calculate_standard_deviation(data):
    variance = calculate_variance(data)
    standard_deviation = variance**0.5  
    print(f"Standard Deviation: {variance}**0.5 = {standard_deviation: .2f}")
    
    return standard_deviation

data = [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
print(f"Data: {data}")

standard_deviation1 = calculate_standard_deviation(data)
mean = calculate_mean(data)
# Out:
# Data: [19, 10, 10, 12, 13, 15, 14, 13, 9, 17]
# Rata-rata: 13.2
# Variansi: 91.6 / 10 = 9.16
# Standard Deviation: 9.16**0.5 =  3.03

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='yellow')


plt.axvline(x=mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean}')
plt.axvline(x=mean - standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean-standard_deviation:.2f}')
plt.axvline(x=mean + standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean+standard_deviation:.2f}')


plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title(f'Std Deviation = {standard_deviation:.2f}')


plt.legend()


plt.show()

# %% [markdown]
# KESIMPULAN
#
# Standar deviasi memberikan hasil sebaran data yang jauh lebih akurat. Sedangkan, grafik range hanya menampilkan sebaran dari data terbesar dan terkecil.

# %% [markdown]
# # no 2

# %% [markdown]
# Range

# %%
def range(data):
    nilai_tertinggi = max(data)
    print(f"Nilai tertinggi: {nilai_tertinggi}")

    nilai_terendah = min(data)
    print(f"Nilai terendah: {nilai_terendah}")

    data_range = max(data) - min(data)
 
    print(f"Range: {nilai_tertinggi} - {nilai_terendah} = {data_range}")  
    
    return data_range


data = [180 , 185 , 175 , 190 , 170 , 195 , 165]
print(f"Data: {data}")

data_range = range(data)
# Out:
# Data: [180, 185, 175, 190, 170, 195, 165]
# Nilai tertinggi: 195
# Nilai terendah: 165
# Range: 195 - 165 = 30

# %%
import matplotlib.pyplot as plt

data = [180 , 185 , 175 , 190 , 170 , 195 , 165]
def range(data):
    nilai_tertinggi = max(data)
    nilai_terendah = min(data)
    data_range = max(data) - min(data)
    return data_range

plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='yellow')

y = 1.5 # The y-coordinate where the line will be drawn
x1 = 4/70*1  # The x-coordinate of the start point
x2 = 66/70*1  # The x-coordinate of the end point


plt.axhline(y=y, xmin=x1, xmax=x2, color='red', linestyle='dashed', linewidth=1, label=f'Range = {range(data)}')

plt.axvline(x=min(data), color='blue', linestyle='dashed', linewidth=1, label=f'Min Data: {min(data):.2f}')
plt.axvline(x=max(data), color='blue', linestyle='dashed', linewidth=1, label=f'Max Data: {max(data):.2f}')


plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Range')


plt.legend()


plt.show()

# %% [markdown]
# Standar Deviasi dan Variansi

# %%
def calculate_mean(data):
    return sum(data) / len(data)

def calculate_variance(data):
    # Rata-rata 
    mean = calculate_mean(data)
    print(f"Rata-rata: {mean}")  
    
    squared_diff = []
    for x in data:
        squared_diff_per_x = (x - mean)**2
        squared_diff.append( squared_diff_per_x ) 
    
    variance = sum(squared_diff) / len(data)
     
    print(f"Variansi: {sum(squared_diff)} / {len(data)} = {variance}")    
    
    return variance

def calculate_standard_deviation(data):
    variance = calculate_variance(data)
    standard_deviation = variance**0.5  
    print(f"Standard Deviation: {variance}**0.5 = {standard_deviation: .2f}")
    
    return standard_deviation

data = [180 , 185 , 175 , 190 , 170 , 195 , 165]
print(f"Data: {data}")

standard_deviation1 = calculate_standard_deviation(data)
mean = calculate_mean(data)
# Out:
# Data: [180, 185, 175, 190, 170, 195, 165]
# Rata-rata: 180.0
# Variansi: 700.0 / 7 = 100.0
# Standard Deviation: 100.0**0.5 =  10.00

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.hist(data, bins=30, edgecolor='black', alpha=0.5, color='yellow')


plt.axvline(x=mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean}')
plt.axvline(x=mean - standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean-standard_deviation:.2f}')
plt.axvline(x=mean + standard_deviation, color='blue', linestyle='dashed', linewidth=1, label=f'{mean+standard_deviation:.2f}')


plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title(f'Std Deviation = {standard_deviation:.2f}')


plt.legend()


plt.show()

# %% [markdown]
# KESIMPULAN
#
# Terlihat bahwa setiap data hanya muncul sekali saja yang membuat persebaran data menjadi merata. Sehingga kita dapat bebas menggunakan standar deviasi maupun range karena data tersebar secara rata.
